# %% [markdown]
# <span style="color:orange">
#  <h2> Databircks-Assignemnt 7 Tables and Views
# </span>
#   <h5>
#     <span style="color:red">
# <b>Author: Deepak Goyal <br>
#    <a> adeus.azurelib.com </a><br>
#    Email at: admin@azurelib.com
# </span>

# %% [markdown]
# <b> Create a database named 'azurelib' inside the databricks

# %%
# Write your code here

# %% [markdown]
# <b> Upload the Employee.csv under the ADLS storage account raw container. Load the file as dataframe in the databricks from ADLS.  Write a Spark SQL code to managed create a table named Employee within the azurelib db to this information

# %%
# Write your code here

# %% [markdown]
# <b> Write a code to pull out all the employee first_name, last_name, gender, email_id whose first_name starts with 'A' from the employee table

# %% [markdown]
# <b>
# Find out all the employees whose salary is greater than average salary. Store all these employee information as external table 'Employee_ext' under /mnt/azurelib/Employee_avg  folder.

# %% [markdown]
# <b>
# Create a one more external table name 'Employee_ext_read' to read all the data stored in the /mnt/azurelib/Employee_avg location.

# %%
# Write your code here

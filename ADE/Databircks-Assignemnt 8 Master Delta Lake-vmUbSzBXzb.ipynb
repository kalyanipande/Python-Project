# %% [markdown]
# <span style="color:orange">
#  <h2> Databircks-Assignemnt 8 Master Delta Lake
# </span>
#   <h5>
#     <span style="color:red">
# <b>Author: Deepak Goyal <br>
#    <a> adeus.azurelib.com </a><br>
#    Email at: admin@azurelib.com
# </span>

# %% [markdown]
# <b> 1. Use Order.csv ingest it into Delta Lake. This data should be saved in a Delta table. Inspect the data using simple SQL commands.

# %%
# Write your code here

# %% [markdown]
# <b>  2. From the above Delta table, create a new Delta table that only contains Orders have UnitsSold greater than 1000.

# %%
# Write your code here

# %% [markdown]
# <b>
#  3. Load the order.csv as parquet table and Write a command to convert the existing Parquet table into a Delta table.

# %%
# Write your code here

# %% [markdown]
# <b>
#  4. How can you add a column Discount to your Delta Lake table using schema evolution? Write the command to perform this operation.

# %%
# Write your code here

# %% [markdown]
# d
# <b>
#  5. Write a command to create a new version of the Delta Lake table where TotalProfit is increased by 10% for all rows.

# %%
# Write your code here

# %% [markdown]
# d
# <b>
#  6. Write a command to restore the Delta Lake table to a previous version using Time Travel.

# %%
# Write your code here

# %% [markdown]
# <b>
#  7. Assume that there are duplicate rows in your data. Write a command to remove these duplicates using Delta Lake's DELETE functionality.

# %%
# Write your code here

# %% [markdown]
# d
# <b>
#  8. Implement an upsert operation (also known as "merge") to the Delta table for a new batch of data Order_new.csv.

# %%
# Write your code here

# %% [markdown]
# <b>
# 9. How can you create a partitioned Delta Lake table? Provide a command to partition the data by Region.

# %%
# Write your code here

# %% [markdown]
# <b>
# 10. Write a command to perform an update operation that sets the OrderPriority to "High" where UnitsSold is more than 1000.

# %%
# Write your code here

# %% [markdown]
# <b>
# 11. Assume you updated some records in the Delta table, but later realized these updates were a mistake. How could you revert your changes using Delta Lake's features? Write the commands to perform this operation.

# %%
# Write your code here

# %% [markdown]
# <b>
#   12. How would you handle schema evolution if a new column ShippingCost was added to your new data (Order3.csv)? Write a command to merge the new data including the new column into the existing table.

# %%
# Write your code here

# %% [markdown]
# <b>
#   13. Using Time Travel, write a command to query the state of your Delta Lake table 5 versions ago.

# %%
# Write your code here

# %% [markdown]
# <b>  14. Write a script to optimize a Delta table by compacting small files into larger ones.

# %%
# Write your code here
